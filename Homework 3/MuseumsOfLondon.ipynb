# %% [markdown]
# # Fundamentals of Database Technologies - Assignment 3 (Part 1)
#
# ## Museums of London
#
# ### Question 1: Download as CSV File
#
# The web data containing the lists of museums in London was imported into Google Docs using Google formula **ImportHTML** (the table containing the list is at index 2). Then the spreadsheet was downloaded as a CSV file using the 'Download as' feature in Google Sheets.
#
# ### Question 2a: Number of Museums per Borough (Sorted Alphabetically)

# %%
import pandas as pd
import requests
import json
from time import sleep

museumsDF = pd.read_csv('MuseumsOfLondon.csv')

# Show first 5 rows only
museumsDF.head()
# Out:
#                                     Name  Image District/ward  \
# 0                          2 Willow Road    NaN     Hampstead
# 1                  7 Hammersmith Terrace    NaN   Hammersmith
# 2                    18 Stafford Terrace    NaN  Holland Park
# 3                    575 Wandsworth Road    NaN       Clapham
# 4  All Hallows-by-the-Tower Crypt Museum    NaN         Tower
#
#                   Borough      Region            Type  \
# 0                  Camden       North  Historic house
# 1  Hammersmith and Fulham        West  Historic house
# 2  Kensington and Chelsea        West  Historic house
# 3                 Lambeth       South  Historic house
# 4          City of London  North East       Religious
#
#                                              Summary
# 0  Operated by the National Trust, modernist terr...
# 1  Former home of Emery Walker, friend and mentor...
# 2  Also known as Linley Sambourne House, home of ...
# 3  Operated by the National Trust, 18th century t...
# 4  Saxon-period Anglican church, museum of church...

# %%
# a. What is the number of museums per Borough (sort alphabetically)?

pd.DataFrame(museumsDF.groupby('Borough').size().sort_index(), columns = ['Number of Museums'])
# Out:
#                         Number of Museums
# Borough
# Barking and Dagenham                    2
# Barnet                                  6
# Bexley                                  4
# Brent                                   1
# Bromley                                 5
# Camden                                 33
# City of London                         13
# Croydon                                 2
# Ealing                                  4
# Enfield                                 2
# Greenwich                              10
# Hackney                                 9
# Hammersmith and Fulham                  4
# Haringey                                2
# Harrow                                  4
# Havering                                4
# Hillingdon                              2
# Hounslow                                9
# Islington                              12
# Kensington and Chelsea                 17
# Kingston upon Thames                    2
# Lambeth                                11
# Lewisham                                2
# Merton                                  7
# Newham                                  1
# Redbridge                               2
# Richmond upon Thames                   17
# Southwark                              23
# Sutton                                  3
# Tower Hamlets                          12
# Waltham Forest                          4
# Wandsworth                              2
# Westminster                            47

# %% [markdown]
# ### Question 2b: Number of Historic Houses per Region (Sorted by Number of Museums)

# %%
# b. For Historic houses, what is their number per Region (sort from the most popular region)?
pd.DataFrame(museumsDF[museumsDF['Type'] == 'Historic house'].groupby('Region').size().sort_values(ascending = False), 
             columns = ['Number of Museums'])
# Out:
#             Number of Museums
# Region
# North                      14
# West                       11
# South West                 10
# North East                  7
# South East                  5
# South                       1

# %% [markdown]
# ### Question 3: Geocoding

# %%
# 3. Try geocoding all museums (you may use name and perhaps something more, e.g. “London”). 
# Return a JSON (indent=2) with: Name, number of found locations, and if there is at least one: latitude and longitude.

def geoCode(address):
    retry = True
    jsonResults = []
    
    # Combine address parts
    finalAdd = ''
    for addPart in address:
        finalAdd = finalAdd + ', ' + addPart
    
    while (retry):
        r = requests.get("https://maps.googleapis.com/maps/api/geocode/json", params = {"address": finalAdd})
        jsonResults = r.json()
        if jsonResults['status'] == 'OK' or jsonResults['status'] == 'ZERO_RESULTS':
            retry = False
            #print(json.dumps(jsonResults, indent = 2))
        else:
            sleep(2)
            
    if jsonResults['status'] != 'ZERO_RESULTS':
        return {"Name": address[0], 
                "Locations": len(jsonResults['results']), 
                "Latitude": jsonResults['results'][0]['geometry']['location']['lat'], 
                "Longitude": jsonResults['results'][0]['geometry']['location']['lng']}
    else:
        return {"Name": address[0], 
                "Locations": len(jsonResults['results'])}

# %%
listdict = []

for i, r in museumsDF.iterrows():
    address = [r['Name']]
    if (pd.notnull(r['District/ward'])):
        address.append(r['District/ward'])
        
    address.append(r['Borough'])
    address.append('London')
        
    listdict.append(geoCode(address))
    sleep(2)

# %%
print(json.dumps(listdict, indent = 2))
# Out:
# [
#   {
#     "Locations": 0,
#     "Name": "2 Willow Road"
#   },
#   {
#     "Longitude": -0.2424588,
#     "Latitude": 51.4898355,
#     "Locations": 1,
#     "Name": "7 Hammersmith Terrace"
#   },
#   {
#     "Longitude": -0.1968857,
#     "Latitude": 51.500476,
#     "Locations": 1,
#     "Name": "18 Stafford Terrace"
#   },
#   {
#     "Longitude": -0.1406211,
#     "Latitude": 51.4696864,
#     "Locations": 1,
#     "Name": "575 Wandsworth Road"
#   },
#   {
#     "Locations": 0,
#     "Name": "All Hallows-by-the-Tower Crypt Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Anaesthesia Heritage Centre"
#   },
#   {
#     "Longitude": -0.1516708,
#     "Latitude": 51.5034719,
#     "Locations": 1,
#     "Name": "Apsley House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Arsenal Football Club Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Art in Perpetuity Trust"
#   },
#   {
#     "Locations": 0,
#     "Name": "artsdepot"
#   },
#   {
#     "Locations": 0,
#     "Name": "Baden-Powell House Exhibition"
#   },
#   {
#     "Locations": 0,
#     "Name": "Bank of England Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Bankside Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Banqueting House, Whitehall"
#   },
#   {
#     "Longitude": -0.093263,
#     "Latitude": 51.5200768,
#     "Locations": 1,
#     "Name": "Barbican Centre"
#   },
#   {
#     "Longitude": -0.202301,
#     "Latitude": 51.6528467,
#     "Locations": 1,
#     "Name": "Barnet Museum"
#   },
#   {
#     "Longitude": -0.4646015,
#     "Latitude": 51.5405025,
#     "Locations": 1,
#     "Name": "Battle of Britain Bunker"
#   },
#   {
#     "Locations": 0,
#     "Name": "Ben Uri Gallery, The London Jewish Museum of Art"
#   },
#   {
#     "Longitude": -0.1249351,
#     "Latitude": 51.5076125,
#     "Locations": 1,
#     "Name": "Benjamin Franklin House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Bentley Priory Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Bethlem Museum of the Mind"
#   },
#   {
#     "Locations": 0,
#     "Name": "Borough Road Gallery"
#   },
#   {
#     "Longitude": -0.3184403,
#     "Latitude": 51.4919623,
#     "Locations": 1,
#     "Name": "Boston Manor House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Brent Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "British Airways Heritage Centre"
#   },
#   {
#     "Locations": 0,
#     "Name": "British Dental Association Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "British Library"
#   },
#   {
#     "Locations": 0,
#     "Name": "British Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "British Optical Association Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "British Postal Museum and Archive"
#   },
#   {
#     "Locations": 0,
#     "Name": "British Red Cross Museum and Archives"
#   },
#   {
#     "Locations": 0,
#     "Name": "Bromley Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Bruce Castle Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Brunei Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Brunel Museum"
#   },
#   {
#     "Longitude": -0.14189,
#     "Latitude": 51.501364,
#     "Locations": 1,
#     "Name": "Buckingham Palace"
#   },
#   {
#     "Locations": 0,
#     "Name": "The Building Centre"
#   },
#   {
#     "Locations": 0,
#     "Name": "Burgh House & Hampstead Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Calvert 22"
#   },
#   {
#     "Locations": 0,
#     "Name": "Camden Arts Centre"
#   },
#   {
#     "Longitude": -0.1291701,
#     "Latitude": 51.5078501,
#     "Locations": 1,
#     "Name": "Canada House Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Carlyle's House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Cartoon Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Centre for Recent Drawing"
#   },
#   {
#     "Longitude": -0.1162628,
#     "Latitude": 51.52359879999999,
#     "Locations": 1,
#     "Name": "Charles Dickens Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Chartered Insurance Institute Museum"
#   },
#   {
#     "Longitude": -0.16235,
#     "Latitude": 51.484447,
#     "Locations": 1,
#     "Name": "Chelsea Physic Garden"
#   },
#   {
#     "Locations": 0,
#     "Name": "Chisenhale Gallery"
#   },
#   {
#     "Longitude": -0.258696,
#     "Latitude": 51.4838077,
#     "Locations": 1,
#     "Name": "Chiswick House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Churchill War Rooms"
#   },
#   {
#     "Locations": 0,
#     "Name": "City of London Police Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Cinema Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Clarence House"
#   },
#   {
#     "Longitude": -0.0918904,
#     "Latitude": 51.5070209,
#     "Locations": 1,
#     "Name": "Clink Prison Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Clowns Gallery-Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Couper Collection"
#   },
#   {
#     "Locations": 0,
#     "Name": "Courtauld Gallery"
#   },
#   {
#     "Longitude": -0.1330912,
#     "Latitude": 51.4985113,
#     "Locations": 1,
#     "Name": "Crime Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Crofton Roman Villa"
#   },
#   {
#     "Locations": 0,
#     "Name": "Crossness Pumping Station"
#   },
#   {
#     "Longitude": -0.0723853,
#     "Latitude": 51.4218504,
#     "Locations": 1,
#     "Name": "Crystal Palace Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Cubitt Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Cuming Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Cutty Sark Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Danson House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Dennis Severs' House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Design Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Dr Johnson's House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Dorich House"
#   },
#   {
#     "Longitude": 0.0527618,
#     "Latitude": 51.33035750000001,
#     "Locations": 1,
#     "Name": "Down House"
#   },
#   {
#     "Longitude": -0.0863698,
#     "Latitude": 51.4459785,
#     "Locations": 1,
#     "Name": "Dulwich Picture Gallery"
#   },
#   {
#     "Longitude": 0.0994164,
#     "Latitude": 51.53432369999999,
#     "Locations": 1,
#     "Name": "Eastbury Manor House"
#   },
#   {
#     "Longitude": 0.048656,
#     "Latitude": 51.4470748,
#     "Locations": 1,
#     "Name": "Eltham Palace"
#   },
#   {
#     "Locations": 0,
#     "Name": "Estorick Collection of Modern Italian Art"
#   },
#   {
#     "Locations": 0,
#     "Name": "Fan Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Faraday Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Fashion and Textile Museum"
#   },
#   {
#     "Longitude": -0.1796628,
#     "Latitude": 51.5588946,
#     "Locations": 1,
#     "Name": "Fenton House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Fleming Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Fleming Collection"
#   },
#   {
#     "Locations": 0,
#     "Name": "Florence Nightingale Museum"
#   },
#   {
#     "Longitude": -0.0688805,
#     "Latitude": 51.6699362,
#     "Locations": 1,
#     "Name": "Forty Hall Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Foundling Museum"
#   },
#   {
#     "Longitude": -0.184825,
#     "Latitude": 51.616124,
#     "Locations": 1,
#     "Name": "Francis Skaryna Belarusian Library and Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Freud Museum"
#   },
#   {
#     "Longitude": -0.215842,
#     "Latitude": 51.470557,
#     "Locations": 1,
#     "Name": "Fulham Palace"
#   },
#   {
#     "Locations": 0,
#     "Name": "Fusiliers Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Galton Collection"
#   },
#   {
#     "Locations": 0,
#     "Name": "Garden Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Garrick's Temple to Shakespeare"
#   },
#   {
#     "Locations": 0,
#     "Name": "Gasworks Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Geffrye Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Goldsmiths' Centre"
#   },
#   {
#     "Locations": 0,
#     "Name": "Golden Hinde"
#   },
#   {
#     "Locations": 0,
#     "Name": "Gordon Museum of Pathology"
#   },
#   {
#     "Locations": 0,
#     "Name": "Grant Museum of Zoology and Comparative Anatomy"
#   },
#   {
#     "Locations": 0,
#     "Name": "Greenwich Heritage Centre"
#   },
#   {
#     "Locations": 0,
#     "Name": "Greenwich Visitor Centre"
#   },
#   {
#     "Locations": 0,
#     "Name": "Guards Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Guildhall Art Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Gunnersbury Park Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Hackney Museum"
#   },
#   {
#     "Longitude": 0.1658315,
#     "Latitude": 51.4513263,
#     "Locations": 1,
#     "Name": "Hall Place"
#   },
#   {
#     "Locations": 0,
#     "Name": "Ham House"
#   },
#   {
#     "Longitude": -0.3377623,
#     "Latitude": 51.4036128,
#     "Locations": 1,
#     "Name": "Hampton Court Palace"
#   },
#   {
#     "Longitude": -0.1459446,
#     "Latitude": 51.5129688,
#     "Locations": 1,
#     "Name": "Handel House Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Harrow Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Havering Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Hayward Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Heath Robinson Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "HMS Belfast"
#   },
#   {
#     "Locations": 0,
#     "Name": "Hogarth's House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Honeywood Museum"
#   },
#   {
#     "Longitude": -0.0878694,
#     "Latitude": 51.5229027,
#     "Locations": 1,
#     "Name": "Honourable Artillery Company Museum"
#   },
#   {
#     "Longitude": -0.061009,
#     "Latitude": 51.441035,
#     "Locations": 1,
#     "Name": "Horniman Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "House of Dreams Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "House of Illustration"
#   },
#   {
#     "Locations": 0,
#     "Name": "Household Cavalry Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "House Mill"
#   },
#   {
#     "Locations": 0,
#     "Name": "Hunterian Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "ICANDO"
#   },
#   {
#     "Locations": 0,
#     "Name": "Imperial War Museum London"
#   },
#   {
#     "Locations": 0,
#     "Name": "Inns of Court & City Yeomanry Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Institute of Archaeology Collections"
#   },
#   {
#     "Locations": 0,
#     "Name": "Institute of Contemporary Arts"
#   },
#   {
#     "Locations": 0,
#     "Name": "Islington Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Jack the Ripper Museum"
#   },
#   {
#     "Longitude": -0.126429,
#     "Latitude": 51.49850199999999,
#     "Locations": 1,
#     "Name": "Jewel Tower"
#   },
#   {
#     "Locations": 0,
#     "Name": "Jewish Museum London"
#   },
#   {
#     "Locations": 0,
#     "Name": "Keats House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Kelmscott House Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Kennel Club Dog Art Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Kensington Palace"
#   },
#   {
#     "Longitude": -0.1676169,
#     "Latitude": 51.571337,
#     "Locations": 1,
#     "Name": "Kenwood House"
#   },
#   {
#     "Longitude": -0.2850662,
#     "Latitude": 51.47714509999999,
#     "Locations": 2,
#     "Name": "Kew Gardens"
#   },
#   {
#     "Longitude": -0.2950194,
#     "Latitude": 51.4838239,
#     "Locations": 1,
#     "Name": "Kew Palace"
#   },
#   {
#     "Longitude": -0.3002937,
#     "Latitude": 51.409571,
#     "Locations": 1,
#     "Name": "Kingston Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Kirkaldy Testing Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "L-13 Light Industrial Workshop"
#   },
#   {
#     "Longitude": -0.1198461,
#     "Latitude": 51.4957797,
#     "Locations": 1,
#     "Name": "Lambeth Palace"
#   },
#   {
#     "Locations": 0,
#     "Name": "Landmark Arts Centre"
#   },
#   {
#     "Locations": 0,
#     "Name": "Langdon Down Museum of Learning Disability"
#   },
#   {
#     "Locations": 0,
#     "Name": "Lethaby Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Leighton House Museum"
#   },
#   {
#     "Longitude": -0.1209864,
#     "Latitude": 51.5151334,
#     "Locations": 1,
#     "Name": "Library and Museum of Freemasonry"
#   },
#   {
#     "Locations": 0,
#     "Name": "Little Holland House"
#   },
#   {
#     "Locations": 0,
#     "Name": "London Canal Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "London Film Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "London Fire Brigade Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "London Motor Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "London Motorcycle Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "London Museum of Water & Steam"
#   },
#   {
#     "Locations": 0,
#     "Name": "London Sewing Machine Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "London Transport Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "London Transport Museum Depot"
#   },
#   {
#     "Locations": 0,
#     "Name": "Madame Tussauds London"
#   },
#   {
#     "Locations": 0,
#     "Name": "Magic Circle Museum"
#   },
#   {
#     "Longitude": -0.08950899999999999,
#     "Latitude": 51.51300699999999,
#     "Locations": 1,
#     "Name": "Mansion House"
#   },
#   {
#     "Longitude": -0.3159597,
#     "Latitude": 51.4497146,
#     "Locations": 1,
#     "Name": "Marble Hill House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Markfield Beam Engine and Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "MCC Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Mall Galleries"
#   },
#   {
#     "Locations": 0,
#     "Name": "Media Space"
#   },
#   {
#     "Locations": 0,
#     "Name": "Merton Heritage Centre"
#   },
#   {
#     "Locations": 0,
#     "Name": "MOCA, London"
#   },
#   {
#     "Locations": 0,
#     "Name": "Morley Gallery"
#   },
#   {
#     "Longitude": -0.3507925,
#     "Latitude": 51.4551373,
#     "Locations": 1,
#     "Name": "Museum of Army Music"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of Asian Music"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of Brands, Packaging and Advertising"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of Comedy"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of Croydon"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of Domestic Design and Architecture"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of Immigration and Diversity"
#   },
#   {
#     "Longitude": -0.1763672,
#     "Latitude": 51.49671499999999,
#     "Locations": 1,
#     "Name": "Museum of Life Sciences"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of London"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of London Docklands"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of Richmond"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of the Order of St John"
#   },
#   {
#     "Locations": 0,
#     "Name": "Museum of Wimbledon"
#   },
#   {
#     "Locations": 0,
#     "Name": "Musical Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "National Army Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "National Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "National Maritime Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "National Portrait Gallery"
#   },
#   {
#     "Longitude": -0.1763672,
#     "Latitude": 51.49671499999999,
#     "Locations": 1,
#     "Name": "Natural History Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Old Operating Theatre Museum and Herb Garret"
#   },
#   {
#     "Longitude": -0.0085135,
#     "Latitude": 51.4827375,
#     "Locations": 1,
#     "Name": "Old Royal Naval College"
#   },
#   {
#     "Locations": 0,
#     "Name": "Old Speech Room Gallery and Museum, Harrow School"
#   },
#   {
#     "Locations": 0,
#     "Name": "Orleans House Gallery"
#   },
#   {
#     "Longitude": -0.345492,
#     "Latitude": 51.489536,
#     "Locations": 1,
#     "Name": "Osterley Park and House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Parasol unit foundation for contemporary art"
#   },
#   {
#     "Locations": 0,
#     "Name": "Peckham Platform"
#   },
#   {
#     "Locations": 0,
#     "Name": "Petrie Museum of Egyptian Archaeology"
#   },
#   {
#     "Locations": 0,
#     "Name": "The Photographers' Gallery"
#   },
#   {
#     "Longitude": -0.3071221,
#     "Latitude": 51.5110189,
#     "Locations": 1,
#     "Name": "Pitzhanger Manor"
#   },
#   {
#     "Locations": 0,
#     "Name": "Polish Institute and Sikorski Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Pollock's Toy Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Pushkin House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Queen Charlotte's Cottage"
#   },
#   {
#     "Locations": 0,
#     "Name": "Queen Elizabeth's Hunting Lodge"
#   },
#   {
#     "Locations": 0,
#     "Name": "Queen's Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Queen's House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Ragged School Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Rainham Hall"
#   },
#   {
#     "Locations": 0,
#     "Name": "Ranger's House (Wernher Collection)"
#   },
#   {
#     "Locations": 0,
#     "Name": "Red House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Red Mansion Foundation"
#   },
#   {
#     "Longitude": 0.0754421,
#     "Latitude": 51.5581311,
#     "Locations": 1,
#     "Name": "Redbridge Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "RCM Museum of Music"
#   },
#   {
#     "Locations": 0,
#     "Name": "Riverside Gallery"
#   },
#   {
#     "Longitude": -0.0793055,
#     "Latitude": 51.5267399,
#     "Locations": 1,
#     "Name": "Rivington Place"
#   },
#   {
#     "Locations": 0,
#     "Name": "Rose Theatre Exhibition"
#   },
#   {
#     "Locations": 0,
#     "Name": "Royal Academy of Arts"
#   },
#   {
#     "Locations": 0,
#     "Name": "Royal Academy of Music Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Royal Air Force Museum London"
#   },
#   {
#     "Longitude": -0.0762738,
#     "Latitude": 51.5079709,
#     "Locations": 1,
#     "Name": "Royal Armouries, Tower of London"
#   },
#   {
#     "Locations": 0,
#     "Name": "Royal College of Physicians Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Royal Hospital Chelsea Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Royal London Hospital Archives and Museum"
#   },
#   {
#     "Longitude": -0.1449564,
#     "Latitude": 51.4989514,
#     "Locations": 1,
#     "Name": "Royal Mews"
#   },
#   {
#     "Locations": 0,
#     "Name": "Royal Observatory, Greenwich"
#   },
#   {
#     "Locations": 0,
#     "Name": "Royal Pharmaceutical Society Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "St Bartholomew's Hospital Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "St Paul's Cathedral"
#   },
#   {
#     "Locations": 0,
#     "Name": "Saatchi Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Science Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Serpentine Galleries"
#   },
#   {
#     "Longitude": -0.09719399999999999,
#     "Latitude": 51.508076,
#     "Locations": 1,
#     "Name": "Shakespeare\u2019s Globe Exhibition"
#   },
#   {
#     "Longitude": -0.1569694,
#     "Latitude": 51.5312705,
#     "Locations": 1,
#     "Name": "Sherlock Holmes Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Shirley Windmill"
#   },
#   {
#     "Locations": 0,
#     "Name": "The Showroom"
#   },
#   {
#     "Locations": 0,
#     "Name": "Sir John Soane's Museum"
#   },
#   {
#     "Longitude": -0.117148,
#     "Latitude": 51.511059,
#     "Locations": 1,
#     "Name": "Somerset House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Soseki Museum in London"
#   },
#   {
#     "Locations": 0,
#     "Name": "South London Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Southside House"
#   },
#   {
#     "Longitude": -0.140191,
#     "Latitude": 51.505187,
#     "Locations": 1,
#     "Name": "Spencer House"
#   },
#   {
#     "Longitude": -0.194297,
#     "Latitude": 51.59691,
#     "Locations": 1,
#     "Name": "Stephens Collection"
#   },
#   {
#     "Longitude": -0.3345635,
#     "Latitude": 51.4382596,
#     "Locations": 1,
#     "Name": "Strawberry Hill"
#   },
#   {
#     "Locations": 0,
#     "Name": "Studio Voltaire"
#   },
#   {
#     "Locations": 0,
#     "Name": "Sutton House"
#   },
#   {
#     "Longitude": -0.312492,
#     "Latitude": 51.4768,
#     "Locations": 1,
#     "Name": "Syon House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Tate Britain"
#   },
#   {
#     "Locations": 0,
#     "Name": "Tate Modern"
#   },
#   {
#     "Longitude": -0.07616669999999999,
#     "Latitude": 51.5043192,
#     "Locations": 1,
#     "Name": "Tower Bridge"
#   },
#   {
#     "Locations": 0,
#     "Name": "Tower of London"
#   },
#   {
#     "Locations": 0,
#     "Name": "Twinings Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Twickenham Museum"
#   },
#   {
#     "Longitude": -0.1122429,
#     "Latitude": 51.51163529999999,
#     "Locations": 1,
#     "Name": "Two Temple Place"
#   },
#   {
#     "Locations": 0,
#     "Name": "Type Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "UCL Art Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "UCL Geology Collections"
#   },
#   {
#     "Locations": 0,
#     "Name": "Upminster Tithe Barn Museum of Nostalgia"
#   },
#   {
#     "Locations": 0,
#     "Name": "Upminster Windmill"
#   },
#   {
#     "Longitude": 0.134181,
#     "Latitude": 51.5582888,
#     "Locations": 1,
#     "Name": "Valence House Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Valentines Mansion"
#   },
#   {
#     "Locations": 0,
#     "Name": "Vestry House Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Victoria and Albert Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "The Viktor Wynd Museum of Curiosities, Fine Art & Natural History"
#   },
#   {
#     "Locations": 0,
#     "Name": "V&A Museum of Childhood"
#   },
#   {
#     "Locations": 0,
#     "Name": "Wallace Collection"
#   },
#   {
#     "Locations": 0,
#     "Name": "Walthamstow Pumphouse Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Wandle Industrial Museum"
#   },
#   {
#     "Longitude": -0.1972314,
#     "Latitude": 51.45698609999999,
#     "Locations": 1,
#     "Name": "Wandsworth Museum"
#   },
#   {
#     "Longitude": -0.133945,
#     "Latitude": 51.525851,
#     "Locations": 1,
#     "Name": "Wellcome Collection"
#   },
#   {
#     "Longitude": -0.1508545,
#     "Latitude": 51.5025925,
#     "Locations": 2,
#     "Name": "Wellington Arch"
#   },
#   {
#     "Locations": 0,
#     "Name": "Wesley's Chapel, Museum of Methodism and John Wesley's House"
#   },
#   {
#     "Locations": 0,
#     "Name": "Westminster Abbey Museum"
#   },
#   {
#     "Longitude": -0.2102055,
#     "Latitude": 51.4679953,
#     "Locations": 1,
#     "Name": "Westminster Dragoons Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "White Lodge Museum and Ballet Resource Centre"
#   },
#   {
#     "Locations": 0,
#     "Name": "Whitechapel Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Whitehall"
#   },
#   {
#     "Locations": 0,
#     "Name": "Whitewebbs Museum of Transport"
#   },
#   {
#     "Longitude": -0.1279393,
#     "Latitude": 51.5216315,
#     "Locations": 1,
#     "Name": "Wiener Library"
#   },
#   {
#     "Locations": 0,
#     "Name": "William Morris Gallery"
#   },
#   {
#     "Locations": 0,
#     "Name": "Wimbledon Lawn Tennis Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "Wimbledon Windmill Museum"
#   },
#   {
#     "Locations": 0,
#     "Name": "World Rugby Museum"
#   }
# ]

# %%
latlongDF = pd.DataFrame(listdict, columns = ['Name', 'Locations', 'Latitude', 'Longitude'])

# Show first 5 rows only
latlongDF.head()
# Out:
#                                     Name  Locations   Latitude  Longitude
# 0                          2 Willow Road          0        NaN        NaN
# 1                  7 Hammersmith Terrace          1  51.489835  -0.242459
# 2                    18 Stafford Terrace          1  51.500476  -0.196886
# 3                    575 Wandsworth Road          1  51.469686  -0.140621
# 4  All Hallows-by-the-Tower Crypt Museum          0        NaN        NaN

# %% [markdown]
# ### Question 4: Merge with Original DataFrame

# %%
# 4. Join (pd.join or pd.merge) it with the original DataFrame.

museumsLatLongDF = pd.merge(museumsDF, latlongDF, on = 'Name')

# Show first 5 rows only
museumsLatLongDF.head()
# Out:
#                                     Name  Image District/ward  \
# 0                          2 Willow Road    NaN     Hampstead
# 1                  7 Hammersmith Terrace    NaN   Hammersmith
# 2                    18 Stafford Terrace    NaN  Holland Park
# 3                    575 Wandsworth Road    NaN       Clapham
# 4  All Hallows-by-the-Tower Crypt Museum    NaN         Tower
#
#                   Borough      Region            Type  \
# 0                  Camden       North  Historic house
# 1  Hammersmith and Fulham        West  Historic house
# 2  Kensington and Chelsea        West  Historic house
# 3                 Lambeth       South  Historic house
# 4          City of London  North East       Religious
#
#                                              Summary  Locations   Latitude  \
# 0  Operated by the National Trust, modernist terr...          0        NaN
# 1  Former home of Emery Walker, friend and mentor...          1  51.489835
# 2  Also known as Linley Sambourne House, home of ...          1  51.500476
# 3  Operated by the National Trust, 18th century t...          1  51.469686
# 4  Saxon-period Anglican church, museum of church...          0        NaN
#
#    Longitude
# 0        NaN
# 1  -0.242459
# 2  -0.196886
# 3  -0.140621
# 4        NaN

# %% [markdown]
# ### Question 5: Average Latitude and Longitude for each Region

# %%
museumsLatLongDF.groupby('Region')['Latitude', 'Longitude'].mean()
# Out:
#              Latitude  Longitude
# Region
# North       51.535715  -0.137575
# North East  51.528017  -0.003739
# North West        NaN        NaN
# South       51.469686  -0.140621
# South East  51.453217  -0.032648
# South West  51.452226  -0.281837
# West        51.491971  -0.267579

# %%
# Number of museums without found location

museumsLatLongDF[museumsLatLongDF['Locations'] == 0].shape[0]
# Out:
# 214
